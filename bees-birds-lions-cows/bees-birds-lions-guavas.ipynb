# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !pip install -q keras
# !pip install -q imutils

# %%
# !ls "/content/drive/My Drive/Colab Notebooks/bees vs birds vs lions vs cows/"
# Out:
#  bees-birds-lions-guavas.ipynb	'test_network (1).py'
#  lenet.py			'train_network (1).py'

# %%
# !python3 "/content/drive/My Drive/Colab Notebooks/bees vs birds vs lions vs cows/train_network (1).py" --dataset "/content/drive/My Drive/Colab Notebooks/bees vs birds/images" --model "/content/drive/My Drive/Colab Notebooks/bees vs birds vs lions vs cows/bees-birds-lions-cows.h5" --plot  "/content/drive/My Drive/Colab Notebooks/bees vs birds vs lions vs cows/plot_new.png"
# Out:
# Using TensorFlow backend.
# [INFO] loading images...
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: profile 'ICC Profile': 1000000h: invalid rendering intent
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# [INFO] compiling model...
# [INFO] training network...
# Epoch 1/25
# 2018-12-11 10:28:40.918091: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-12-11 10:28:40.918528: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# ...

# %%
from google.colab import files
files.download('plot.png')

# %% [markdown]
# # **Now test on different bee vs bird images**

# %%
# !python3 "/content/drive/My Drive/Colab Notebooks/bees vs birds vs lions vs cows/test_network (1).py" --model "/content/drive/My Drive/Colab Notebooks/bees vs birds vs lions vs cows/bees-birds-lions-cows.h5"  --image "/content/drive/My Drive/Colab Notebooks/bees vs birds vs lions vs cows/test_images/bee2.jpg"
# Out:
# Using TensorFlow backend.
# [INFO] loading network...
# 2018-12-11 11:08:17.996629: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-12-11 11:08:17.997089: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2018-12-11 11:08:17.997131: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# 2018-12-11 11:08:18.415984: I tensorflow/core/common_runtime/gpu/gpu_device.cc:982] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-12-11 11:08:18.416038: I tensorflow/core/common_runtime/gpu/gpu_device.cc:988]      0
# 2018-12-11 11:08:18.416067: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1001] 0:   N
# ...
