# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# !pip install -q keras
# !pip install -q imutils

# %%
# !ls "/content/drive/My Drive/Colab Notebooks/"
# Out:
# 'bees vs birds'  'lions vs dogs'   MNIST

# %%
# !python3 "/content/drive/My Drive/Colab Notebooks/bees vs birds/train_network.py" --dataset "/content/drive/My Drive/Colab Notebooks/bees vs birds/images" --model "/content/drive/My Drive/Colab Notebooks/bees vs birds/bees-birds.h5" --plot  "/content/drive/My Drive/Colab Notebooks/bees vs birds/plot_new.png"
# Out:
# Using TensorFlow backend.
# [INFO] loading images...
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: profile 'ICC Profile': 1000000h: invalid rendering intent
# libpng warning: iCCP: known incorrect sRGB profile
# [INFO] compiling model...
# [INFO] training network...
# Epoch 1/25
# 2018-12-10 14:20:29.024268: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-12-10 14:20:29.024761: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2018-12-10 14:20:29.024828: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# ...

# %%
from google.colab import files
files.download('plot.png')

# %% [markdown]
# # **Now test on different bee vs bird images**

# %%
# !python3 "/content/drive/My Drive/Colab Notebooks/bees vs birds/test_network.py" --model "/content/drive/My Drive/Colab Notebooks/bees vs birds/bees-birds.h5"  --image "/content/drive/My Drive/Colab Notebooks/bees vs birds/bee4.jpg"
# Out:
# Using TensorFlow backend.
# [INFO] loading network...
# 2018-12-11 06:34:22.957414: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-12-11 06:34:22.957937: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2018-12-11 06:34:22.957983: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# 2018-12-11 06:34:23.421113: I tensorflow/core/common_runtime/gpu/gpu_device.cc:982] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-12-11 06:34:23.421174: I tensorflow/core/common_runtime/gpu/gpu_device.cc:988]      0
# 2018-12-11 06:34:23.421201: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1001] 0:   N
# ...
